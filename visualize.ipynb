# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the .npz file
data = np.load('pred.npz')

img = data['0.png']
img = np.transpose(img, (1, 2, 0))

plt.imshow(img)
plt.title('RGB Image')
plt.axis('off')
plt.show()

# %%
img = data['1.png']
img = np.transpose(img, (1, 2, 0))

plt.imshow(img)
plt.title('RGB Image')
plt.axis('off')
plt.show()

# %%
img = data['2.png']
img = np.transpose(img, (1, 2, 0))

plt.imshow(img)
plt.title('RGB Image')
plt.axis('off')
plt.show()
